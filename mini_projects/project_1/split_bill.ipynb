# %% [markdown]
# # Splitsy Code Tester Notebook
# Perpuse: This notebook is for testing code snippets related to the Splitsy project proposal. It will be used to experiment with different approaches to input validation, rounding, and result presentation.
# ## 1. Split Bill Feature: Evenly

# %%
# Function 1: compute_total(subtotal, tax, tip)
def compute_total(subtotal, tax, tip):
    """ given the integer values for subtotal, tax, and tip this fuction will add all the values and return the total """
    total = subtotal + tax + tip
    print("The Bill Total is: $",total)
    return total

# %%
compute_total(45.50, 10.55, 10)
# Out:
# The Bill Total is: $ 66.05
# 66.05
