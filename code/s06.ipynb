# %% [markdown]
# Session 6 Code from Class

# %% [markdown]
# ## Review Questions

# %%
for i in range (4,8):
    print ("iteration:", i)
    print ("square:", i*i)
    print()
# Out:
# iteration: 4
# square: 16
#
# iteration: 5
# square: 25
#
# iteration: 6
# square: 36
#
# iteration: 7
# square: 49

# %%
for i in range (1,9,3):
    print (i)
# Out:
# 1
# 4
# 7

# %%
name = "Alejandro"
type(name)
name[0]
name[0:4]
name[0:7:2]
name[-1]
name [-4:]
# Out:
# 'ndro'

# %%
print(name * 3)
# Out:
# AlejandroAlejandroAlejandro

# %%
print (name + 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print (name + 3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print (name + "3")
# Out:
# Alejandro3

# %%
def double(number):
    """multiply number by 2 and return the result"""
    return number * 2

# %%
print (double (5))
# Out:
# 10

# %%
print ("Finn says \"Hello!\" to Jake.") # escape quotes within a string
# Out:
# Finn says "Hello!" to Jake.

# %%
print (double("hi"))
# Out:
# hihi

# %%
# int is immutable
a = 5
b= a
a = 10
print (a)
print (b)
# Out:
# 10
# 5

# %%
# list is mutable
a = [1,2,3]
b = a
a.append (4)
print (a)
print (b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
x = 10 
def f():
    message = 'hello' # this statement is useless
    x = 5
    return x

print (f()) # returns 5 because x inside f() is a local variable
print (x) # returns 10 because x inside f() is a local variable this x is global
print (message) # error because message is a local variable inside f()
# Out:
# 5
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 9
#       7 print (f()) # returns 5 because x inside f() is a local variable
#       8 print (x) # returns 10 because x inside f() is a local variable this x is global
# ----> 9 print (message)
#
# NameError: name 'message' is not defined

# %% [markdown]
# ## 🧱🧱🧱
# # to get an emojy you have to use the window key and period

# %%
# Draw a square 
"""🧱🧱🧱🧱
"""

# %%
def draw_square(size):
    """Draw a square of given size using bricks"""
    for i in range (size):
        #print ("🧱" * size)
        for j in range (size):
            print ("🧱", end="")
        print ()

# %%
draw_square(4)
# Out:
# 🧱🧱🧱🧱
# 🧱🧱🧱🧱
# 🧱🧱🧱🧱
# 🧱🧱🧱🧱

# %%
# create a function to draw a triangle
🧱 ---------1 = 0+1
🧱🧱-------2 = 1+1
🧱🧱🧱----3 = 2+1
🧱🧱🧱🧱--4 = 3+1

# %%
# In row i, how many bricks are there? i + 1
def draw_triangle(rows):
    """Draw a triangle with given number of rows using bricks"""
    for i in range (1, rows + 1):
        print ("🧱" * i)

# %%
draw_triangle(5)
# Out:
# 🧱
# 🧱🧱
# 🧱🧱🧱
# 🧱🧱🧱🧱
# 🧱🧱🧱🧱🧱

# %% [markdown]
# Draw a triangle like this (size = 5)
#
#      #   0  4 spaces + 1# = 5
#     ##   1  3 spaces + 2# = 5
#    ###   2  2 spaces + 3# = 5
#   ####   3  1 spaces + 4# = 5
# ######   4  0 spaces + 5# = 5

# %%
def draw_triangle(size):
    for i in range ()
